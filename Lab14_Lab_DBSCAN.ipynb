# %% [markdown]
# <a href="https://colab.research.google.com/github/Dejisimple/CSC-587_Colabs/blob/main/Lab14_Lab_DBSCAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Use a real dataset:
# * Try load_iris() from sklearn.datasets.
# * Apply DBSCAN

# %%
from sklearn.datasets import load_iris

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

# %%
iris = load_iris()
X = iris.data
y_true = iris.target

# %% [markdown]
# #Generate a 2D dataset with non-convex clusters

# %%
X, y = make_moons(n_samples=300, noise=0.05, random_state=42)

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Visualize
plt.scatter(X_scaled[:, 0], X_scaled[:, 1])
plt.title("Dataset for DBSCAN")
plt.show()

# %% [markdown]
# #Applying DBSCAN

# %%
dbscan = DBSCAN(eps=0.3, min_samples=5)
labels = dbscan.fit_predict(X_scaled)

# Plot clusters
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=labels, cmap='plasma')
plt.title("DBSCAN Clustering")
plt.show()

# %% [markdown]
# #Can you change epsilon and min values to observe how things change? For instance,
#
# * Try eps=0.1, eps=0.5 and observe the difference.
# * What happens when you change min_samples to 3 or 10?
# * Can you also identify noise for each trial. (Hint: np.sum(labels == -1) after you your clusters)

# %%
eps_values = [0.1, 0.3, 0.5]
min_samples_values = [3, 5, 10]

print("eps_values:", eps_values)
print("min_samples_values:", min_samples_values)
# Out:
# eps_values: [0.1, 0.3, 0.5]
# min_samples_values: [3, 5, 10]

# %% [markdown]
# #Use a real dataset:
# * Try load_iris() from sklearn.datasets.
# * Apply DBSCAN

# %%
from sklearn.datasets import load_iris

# %% [markdown]
# # Task
# Apply DBSCAN with varying `eps` values (0.1, 0.3, 0.5) and `min_samples` values (3, 5, 10) to the `X_scaled` dataset. For each combination, visualize the resulting clusters and noise points, display the number of noise points, and describe how these parameter changes impact the clustering and noise detection.

# %% [markdown]
# ## Define Parameters
#
# ### Subtask:
# Define the different combinations of `eps` and `min_samples` to be tested.

# %% [markdown]
# **Reasoning**:
# The subtask requires defining specific lists for `eps_values` and `min_samples_values`, which can be achieved by creating them directly in a Python code block.

# %% [markdown]
# # Task
# Import `load_iris` from `sklearn.datasets`.

# %% [markdown]
# ## Import load_iris
#
# ### Subtask:
# Import `load_iris` from `sklearn.datasets` to resolve the `NameError`.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
# *   The `load_iris` function was successfully imported from the `sklearn.datasets` module.
#
# ### Insights or Next Steps
# *   The next step will likely involve calling the imported `load_iris` function to load the Iris dataset for subsequent data analysis or model training.
